# %%
import gym
from gym import wrappers
import math, os, random
import numpy as np
import matplotlib
import matplotlib.pyplot as plt
get_ipython().run_line_magic('matplotlib', 'inline')

from collections import namedtuple
from collections import deque
from itertools import count
from PIL import Image

import torch
import torch.nn as nn
import torch.optim as optim
import torch.nn.functional as F
from torch.autograd import Variable
import torchvision.transforms as T

import ppaquette_gym_super_mario


checkpoint_dir = './checkpoints/'
os.environ["CUDA_DEVICE_ORDER"]="PCI_BUS_ID"
os.environ["CUDA_VISIBLE_DEVICES"]="0"
use_cuda = torch.cuda.is_available()
FloatTensor = torch.cuda.FloatTensor if use_cuda else torch.FloatTensor
LongTensor = torch.cuda.LongTensor if use_cuda else torch.LongTensor
ByteTensor = torch.cuda.ByteTensor if use_cuda else torch.ByteTensor
print('CUDA!!!!!',use_cuda)

env = gym.make('ppaquette/SuperMarioBros-1-1-v0')
env = wrappers.Monitor(env, 'gym-results', force=True)

train = True
retrain = False



input_size = np.array([env.observation_space.shape[0], env.observation_space.shape[1], 15])
output_size = 13

dis = 0.9
REPLAY_MEMORY = 20000



def ddqn_replay_train(mainDQN, targetDQN, train_batch, l_rate):
    x_stack = np.empty(0).reshape(0, mainDQN.input_size[0]*mainDQN.input_size[1]*mainDQN.input_size[2])
    y_stack = np.empty(0).reshape(0, mainDQN.output_size)
    action_stack = np.empty(0).reshape(0, 60)
    for state, action_seq, action_next_seq, action , reward, next_state, done in train_batch:
        Q = mainDQN(state, action_seq)
        if done:
            Q[0, action] = reward
        else:
            Q[0, action] = reward + dis * targetDQN(next_state, action_next_seq).max(1)[0]
            
            
        if state is None:
            print("None State, ", action, ", ", reward, ", ", next_state,", ", done)
        else:
            y_stack = np.vstack([y_stack, Q.cpu().data.numpy()])
            x_stack = np.vstack([x_stack, state.reshape(-1, mainDQN.input_size[0]*mainDQN.input_size[1]*mainDQN.input_size[2])])
            action_stack = np.vstack([action_stack, np.reshape(action_seq, (-1, 60))])
    
    Qpred = mainDQN(x_stack, action_stack)
    loss = F.mse_loss(Qpred, Variable(torch.Tensor(y_stack)).type(FloatTensor))
    optm = optim.Adam(mainDQN.parameters())
    optm.zero_grad()
    loss.backward()
    optm.step()
    
    return loss


def bot_play(mainDQN, env=env):
    start = env.reset()
    reward_sum = 0
    while True:
        if state in None or state.size ==1:
            output = random.randint(0, output_size-1)
            action = OutputToAction3(output)
            print("random action:", output)
        else:
            output = np.argmax(mainDQN(state))
            action = OutputToAction3(output)
            print("predicted action:", output)
        for n in range(len(action)):
            state, reward, done, info = env.step(action[n])
            if done:
                break
        reward_sum += reward
        if done:
            print("Total score", reward_sum)
            break
            
def OutputToAction3(output):
    actions={ # A: jump , B: run
        '0' :[[0,0,0,0,0,0], 'Nope'],
        '1' :[[1,0,0,0,0,0], 'Up'],
        '2' :[[0,0,1,0,0,0], 'Down'],
        '3' :[[0,1,0,0,0,0], 'Left'],
        '4' :[[0,1,0,0,1,0], 'Left + A'],
        '5' :[[0,1,0,0,0,1], 'Left + B'],
        '6' :[[0,1,0,0,1,1], 'Left + A + B'],
        '7' :[[0,0,0,1,0,0], 'Right'],
        '8' :[[0,0,0,1,1,0], 'Right + A'],
        '9' :[[0,0,0,1,0,1], 'Right + B'],
        '10':[[0,0,0,1,1,1], 'Right + A + B'],
        '11':[[0,0,0,0,1,0], 'A'],
        '12':[[0,0,0,0,1,1], 'A + B']
    }
    return [np.array([actions[str(output)][0]]*2), actions[str(output)][1]]
    





class DQN(nn.Module):
    def __init__ (self, input_size, output_size):
        super(DQN, self).__init__()
        
        self.input_size = input_size
        self.output_size = output_size
        
        self.model1 = nn.Sequential(
            nn.Conv2d(15,64,3,1),
            nn.ReLU(),
            nn.Conv2d(64,64,3,2),
            nn.ReLU(),
            
            nn.Conv2d(64,128,3,1),
            nn.ReLU(),
            nn.Conv2d(128,128,3,1),
            nn.ReLU(),
            nn.Conv2d(128,128,3,2),
            
            nn.Conv2d(128,256,3,1),
            nn.ReLU(),
            nn.Conv2d(256,256,3,1),
            nn.ReLU(), 
            nn.Conv2d(256,256,3,2),
            
            nn.Conv2d(256,512,3,1),
            nn.ReLU(),
            nn.Conv2d(512,512,3,1),
            nn.ReLU(),
            nn.Conv2d(512,512,3,2),
            
            nn.Conv2d(512,512,3,1),
            nn.ReLU(),
            nn.Conv2d(512,512,3,1),
            nn.ReLU(),
            nn.Conv2d(512,512,3,2),
            
            nn.Conv2d(512,100,[2,3],1),
            nn.ReLU()
            
        )
        self.model2 = nn.Sequential(
            nn.Linear(160,160),
            nn.ReLU(),
            nn.Linear(160,50),
            nn.ReLU(),
            nn.Linear(50,self.output_size)
        )
    def forward(self, x, y):
        #x = np.ascontiguousarray(x, dtype=np.float32)
        x = np.reshape(x, [-1, 224,256,15])
        x = np.transpose(x, (0,3,1,2))
        x = Variable(torch.Tensor(x)).type(FloatTensor)
        y = Variable(torch.from_numpy(np.array(y))).type(FloatTensor)
        x = self.model1(x)
        x = x.view(x.size(0), 100)
        y = y.view(-1, 60)
        z = torch.cat((x,y),1)
        return self.model2(z)
    
   



def main():
    if train:
        init_episode = 1
        max_episode = 10000
        replay_buffer = deque()
        state_buffer = deque()
        next_state_buffer = deque()
        output_buffer = deque()
        
        mainDQN = DQN(input_size, output_size)
        targetDQN = DQN(input_size, output_size)
        targetDQN.load_state_dict(mainDQN.state_dict())
        
        
        if retrain:
            mainDQN = torch.load(mainDQN, 'checkpoints/mainDQN.pt')
            
        if use_cuda:
            mainDQN.cuda()
            targetDQN.cuda()
        
        for episode in range(init_episode, max_episode):
            e = 1.0 / (episode/500 + 1)
            print ("episode:", episode, ", epsilon: ", e)
            done = False
            step_count = 0
            state = env.reset()
            score = 0
            distance = 0
            prev_output = -1
            repeat = 0
            
            while not done:
                if np.random.rand(1) < e or state is None or state.size == 1 or step_count <=10:
                    output = random.randint(0, output_size -1)
                    action,action_name = OutputToAction3(output)
                    print("random action:", action_name)
                
                else:
                    predicted = mainDQN(acc_state, output_seq)
                    output = int(predicted.max(1)[1].view(1,1))
                    action,action_name = OutputToAction3(output)
                    print("output:",action_name, "predicted:", predicted)
                    
                for n in range(len(action)):
                    next_state, reward, done, info = env.step(action[n])
                    if done:
                        print('%dth:' %n)
                        break
                
                print('reward: ', reward)
                state_buffer.append(next_state)
                output_buffer.append(action)
                
                prev_distance = distance
                distance = info['distance']
                got_distance = distance - prev_distance
                
                past_score = score
                score = info['score']
                got_score = score - past_score
                
                time = info['time']
                
                reward = got_score/50 + got_distance/30
                
                if reward>0:
                    print("reward:", reward)
                if done:
                    reward -= 1.0
                    if distance>=3000:
                        reward = 1
                    print("last reward: ", reward)
                
                if step_count>=10:
                    acc_state = [state_buffer[-2-k] for k in range(5)]
                    state_buffer.popleft()
                    acc_state = np.reshape(acc_state, input_size[:3])
                    acc_next_state = [state_buffer[-1-k] for k in range(5)]
                    acc_next_state = np.reshape(acc_next_state, input_size[:3])
                    
                    output_seq = [output_buffer[-2-k] for k in range(5)]
                    output_next_seq = [output_buffer[-1-k] for k in range(5)]
                    output_buffer.popleft()
                    
                    replay_buffer.append((acc_state, output_seq, output_next_seq, output, reward, acc_next_state, done))
                    
                    if replay_buffer[-1][6]:
                        for k in range(1, 5):
                            replay_buffer[-1-k] = tuple(
                                replay_buffer[-1-k][0:4] + (-pow(0.9,k),) + replay_buffer[-1-k][5:]) # ??????
                    if replay_buffer[-1][4] > 2.0 and replay_buffer[-1][6] == False:
                        for k in range(1, 5):
                            replay_buffer[-1-k] = tuple(
                                replay_buffer[-1-k][0:4] + (pow(0.9,k),) + replay_buffer[-1-k][5:])
                    
                    if len(replay_buffer) > REPLAY_MEMORY:
                        replay_buffer.popleft()
                    acc_state = acc_next_state
                    
                state = next_state
                step_count += 1
            if step_count > 100000:
                break

            if (episode+1) % 1 == 0:
                for _ in range(50):
                    if len(replay_buffer) >= 10:
                        sample_idx = random.sample(range(0, len(replay_buffer)), 10)
                        minibatch = []
                        for i in sample_idx:
                            minibatch.append(replay_buffer[i])

                        l_rate = (1e-5 - 1e-4)*(1/max_episode)*episode + 1e-4
                        loss = ddqn_replay_train(mainDQN, targetDQN, minibatch, l_rate=l_rate)

                        print("Loss: %.3f,  l_rate: %.6f" %(loss, l_rate))

            if (episode+1) % 2 == 0:
                targetDQN.load_state_dict(mainDQN.state_dict())
                print('weights copied')

            if (episode+1) % 100 == 0:

                torch.save(mainDQN, 'checkpoints/mainDQN.pt')
            
            #env2 = wrappers.Monitor(env, 'gym-results', force=True)
            #for i in range(200):
            #    bot_play(mainDQN, env=env2)
            #env2.close()
    else:
        mainDQN = DQN(input_size, output_size)
        targetDQN = DQN(input_size, output_size)
        for i in range(200):
            bot_play(mainDQN, env=env)
        env.close()
        
if __name__ == "__main__":
    main()
# Out:
# CUDA!!!!! True
# episode: 1 , epsilon:  0.998003992015968
# random action: Left + B
# reward:  0
# reward: 1.3
# random action: Up
# reward:  0
# random action: Left
# reward:  0
# random action: Left + A + B
# reward:  -2
# random action: Right
# reward:  -1
# random action: Up
# reward:  -1
# random action: Up
# reward:  0
# random action: Right + A
# reward:  -1
# random action: Down
# reward:  0
# random action: Up
# reward:  0
# random action: A + B
# reward:  0
# random action: Right + A
# reward:  0
# random action: Right + A
# reward:  2
# reward: 0.1
# random action: Left
# reward:  1
# reward: 0.1
# random action: Right + A
# reward:  1
# reward: 0.06666666666666667
# random action: Down
# reward:  2
# reward: 0.13333333333333333
# random action: A + B
# reward:  2
# reward: 0.13333333333333333
# random action: Left + B
# reward:  1
# reward: 0.1
# random action: Left + A + B
# reward:  -1
# random action: Left + B
# reward:  -1
# random action: Right + B
# reward:  -1
# random action: Up
# reward:  -1
# random action: Left + A
# reward:  -1
# random action: Down
# reward:  0
# random action: Nope
# reward:  0
# random action: A + B
# reward:  0
# random action: Left
# reward:  0
# random action: Left + A
# reward:  0
# random action: Left
# reward:  -2
# random action: Left + A + B
# reward:  -2
# random action: A + B
# reward:  -2
# random action: Left
# reward:  -2
# random action: Right + A
# reward:  -1
# random action: Right + B
# reward:  -1
# random action: Left
# reward:  -1
# random action: A + B
# reward:  -1
# random action: Left + A + B
# reward:  -2
# random action: Up
# reward:  -2
# random action: A + B
# reward:  0
# random action: Right + A
# reward:  1
# reward: 0.03333333333333333
# random action: A
# reward:  1
# reward: 0.06666666666666667
# random action: Down
# reward:  0
# reward: 0.03333333333333333
# random action: Left
# reward:  0
# reward: 0.03333333333333333
# random action: Up
# reward:  0
# random action: Down
# reward:  0
# random action: Right + B
# reward:  0
# random action: A + B
# reward:  1
# reward: 0.06666666666666667
# random action: Right + A
# reward:  1
# reward: 0.03333333333333333
# random action: A
# reward:  1
# reward: 0.1
# random action: Left + B
# reward:  1
# reward: 0.06666666666666667
# random action: A + B
# reward:  1
# reward: 0.06666666666666667
# random action: A + B
# reward:  1
# reward: 0.03333333333333333
# random action: Nope
# reward:  1
# reward: 0.06666666666666667
# random action: Right + B
# reward:  1
# reward: 0.03333333333333333
# random action: A + B
# reward:  1
# reward: 0.1
# random action: Nope
# reward:  1
# reward: 0.1
# random action: Down
# reward:  2
# reward: 0.1
# random action: Left + A
# reward:  1
# reward: 0.06666666666666667
# random action: Up
# reward:  1
# reward: 0.06666666666666667
# random action: Left + A + B
# reward:  -1
# random action: Left + A + B
# reward:  -1
# random action: A + B
# reward:  0
# random action: A + B
# reward:  0
# random action: Left + B
# reward:  -1
# random action: Right + A + B
# reward:  0
# random action: Up
# reward:  0
# random action: Left + A + B
# reward:  0
# random action: Down
# reward:  -1
# random action: Left + A
# reward:  -1
# random action: A + B
# reward:  0
# random action: Down
# reward:  0
# random action: Up
# reward:  0
# random action: Right + B
# reward:  0
# random action: Left
# reward:  0
# random action: Down
# reward:  0
# random action: Up
# reward:  0
# random action: Left + A + B
# reward:  0
# random action: A
# reward:  0
# random action: Right + A + B
# reward:  -1
# random action: Right + A
# reward:  1
# reward: 0.03333333333333333
# random action: Left + A + B
# reward:  0
# reward: 0.03333333333333333
# random action: Right + A
# reward:  0
# random action: Left
# reward:  0
# reward: 0.03333333333333333
# random action: Right + B
# reward:  0
# random action: Right + A
# reward:  1
# reward: 0.06666666666666667
# random action: Left + B
# reward:  1
# reward: 0.06666666666666667
# random action: Down
# reward:  1
# reward: 0.03333333333333333
# random action: Left
# reward:  0
# random action: Down
# reward:  0
# random action: A
# reward:  0
# random action: Left + A
# reward:  0
# random action: A
# reward:  0
# random action: Right + B
# reward:  0
# random action: Right + B
# reward:  0
# random action: Right
# reward:  2
# reward: 0.1
# random action: Right
# reward:  2
# reward: 0.13333333333333333
# random action: Right + B
# reward:  4
# reward: 0.23333333333333334
# random action: Right + A + B
# reward:  4
# reward: 0.26666666666666666
# random action: Down
# reward:  5
# reward: 0.3333333333333333
# random action: Nope
# reward:  4
# reward: 0.3
# random action: Up
# reward:  5
# reward: 0.3333333333333333
# random action: Left
# reward:  5
# reward: 0.3
# random action: Right
# reward:  4
# reward: 0.26666666666666666
# random action: Right + B
# reward:  4
# reward: 0.23333333333333334
# random action: Right + A + B
# reward:  5
# reward: 0.3333333333333333
# random action: Right
# reward:  6
# reward: 0.36666666666666664
# random action: Down
# reward:  6
# reward: 0.4
# random action: A
# reward:  6
# reward: 0.4
# random action: A
# reward:  6
# reward: 0.4
# random action: Right
# reward:  5
# reward: 0.36666666666666664
# random action: Right
# reward:  4
# reward: 0.23333333333333334
# random action: A
# reward:  4
# reward: 0.23333333333333334
# random action: Left
# reward:  3
# reward: 0.2
# random action: Right + B
# reward:  4
# reward: 0.23333333333333334
# random action: A
# reward:  4
# reward: 0.23333333333333334
# random action: Right + A
# reward:  4
# reward: 0.23333333333333334
# random action: Right + A
# reward:  4
# reward: 0.23333333333333334
# random action: Right + A
# reward:  4
# reward: 0.23333333333333334
# random action: Right + A
# reward:  4
# reward: 0.23333333333333334
# random action: Right + B
# reward:  4
# reward: 0.23333333333333334
# random action: Left + B
# reward:  3
# reward: 0.26666666666666666
# random action: Right + B
# reward:  4
# reward: 0.23333333333333334
# random action: Left + B
# reward:  4
# reward: 0.26666666666666666
# random action: A + B
# reward:  3
# reward: 0.16666666666666666
# random action: Right + B
# reward:  4
# reward: 0.23333333333333334
# random action: Nope
# reward:  4
# reward: 0.23333333333333334
# random action: Right + A
# reward:  4
# reward: 0.23333333333333334
# random action: Right + A
# reward:  4
# reward: 0.23333333333333334
# random action: Left + A + B
# reward:  3
# reward: 0.2
# random action: Right
# reward:  3
# reward: 2.1666666666666665
# random action: A + B
# reward:  4
# reward: 0.23333333333333334
# random action: Up
# reward:  4
# reward: 0.23333333333333334
# random action: Down
# reward:  4
# reward: 0.23333333333333334
# random action: Nope
# reward:  2
# reward: 0.16666666666666666
# random action: A + B
# reward:  1
# reward: 0.1
# random action: Right + B
# reward:  3
# reward: 0.16666666666666666
# random action: Left + A + B
# reward:  2
# reward: 0.16666666666666666
# random action: Up
# reward:  2
# reward: 0.1
# random action: Left
# reward:  1
# reward: 0.06666666666666667
# random action: Up
# reward:  0
# random action: A + B
# reward:  0
# random action: Right + B
# reward:  1
# reward: 0.03333333333333333
# random action: Nope
# reward:  2
# reward: 0.1
# random action: A + B
# reward:  1
# reward: 0.06666666666666667
# random action: Left
# reward:  0
# reward: 0.03333333333333333
# random action: Right + A + B
# reward:  1
# reward: 0.03333333333333333
# random action: Left + A + B
# reward:  -1
# random action: Left + B
# reward:  -1
# random action: Left + A + B
# reward:  -2
# random action: Right + A + B
# reward:  -2
# random action: Right + B
# reward:  -1
# random action: Right + A + B
# reward:  -1
# random action: Down
# reward:  -1
# random action: Left + A
# reward:  -1
# random action: Left + A
# reward:  -2
# random action: Right + A
# reward:  -1
# random action: Up
# reward:  0
# random action: Down
# reward:  0
# random action: A
# reward:  0
# random action: Right
# reward:  1
# reward: 0.03333333333333333
# random action: Right + B
# reward:  1
# reward: 0.03333333333333333
# random action: Left
# reward:  1
# reward: 0.06666666666666667
# random action: Right + B
# reward:  1
# reward: 0.03333333333333333
# random action: Down
# reward:  0
# reward: 0.03333333333333333
# random action: Right
# reward:  1
# reward: 0.03333333333333333
# random action: Nope
# reward:  0
# random action: Left
# reward:  0
# random action: Down
# reward:  0
# random action: Left + A
# reward:  0
# random action: A + B
# reward:  -1
# random action: Right + A + B
# reward:  0
# random action: Left + B
# reward:  0
# random action: Right + A + B
# reward:  0
# random action: A
# reward:  0
# random action: Down
# reward:  0
# random action: Right + A + B
# reward:  0
# random action: Right + A
# reward:  0
# reward: 0.03333333333333333
# random action: A + B
# reward:  1
# reward: 0.06666666666666667
# random action: Right + A + B
# reward:  2
# reward: 0.1
# random action: A
# reward:  2
# reward: 0.1
# random action: A + B
# reward:  0
# random action: A + B
# reward:  0
# random action: Right
# reward:  1
# reward: 0.03333333333333333
# random action: Left + B
# reward:  -1
# random action: Down
# reward:  0
# random action: Right + A + B
# reward:  1
# reward: 0.03333333333333333
# random action: A
# reward:  1
# reward: 0.03333333333333333
# random action: Right + A
# reward:  2
# reward: 0.1
# random action: Right + A
# reward:  2
# reward: 0.13333333333333333
# random action: Right + B
# reward:  4
# reward: 0.23333333333333334
# random action: Nope
# reward:  3
# reward: 0.23333333333333334
# random action: Right
# reward:  4
# reward: 0.26666666666666666
# random action: Right
# reward:  3
# reward: 0.23333333333333334
# random action: Left + B
# reward:  3
# reward: 0.23333333333333334
# random action: Up
# reward:  2
# reward: 0.13333333333333333
# random action: A
# reward:  2
# reward: 0.13333333333333333
# random action: Left + A
# reward:  1
# reward: 0.06666666666666667
# random action: Up
# reward:  0
# reward: 0.03333333333333333
# random action: Left + A + B
# reward:  0
# reward: 0.03333333333333333
# random action: Nope
# reward:  -1
# random action: Down
# reward:  0
# random action: Left + B
# reward:  0
# random action: Left
# reward:  0
# reward: 20.0
# random action: Down
# reward:  0
# random action: Left
# reward:  0
# random action: Nope
# reward:  0
# random action: Left + A
# reward:  0
# random action: A + B
# reward:  0
# random action: Left
# reward:  0
# random action: Left + B
# reward:  0
# random action: Left + A
# reward:  0
# random action: Right + B
# reward:  0
# random action: Nope
# reward:  0
# random action: Left + B
# reward:  0
# random action: A
# reward:  0
# random action: Right
# reward:  0
# random action: Right + B
# reward:  0
# random action: Left + B
# reward:  -1
# random action: A
# reward:  -1
# random action: Left
# reward:  1
# reward: 0.03333333333333333
# random action: Left + A + B
# reward:  0
# reward: 0.06666666666666667
# random action: Right + A
# reward:  0
# random action: A
# reward:  1
# reward: 0.03333333333333333
# random action: Left + B
# reward:  -1
# random action: Up
# reward:  0
# random action: Right + B
# reward:  0
# random action: Left + B
# reward:  -1
# random action: Nope
# reward:  0
# random action: Right + A
# reward:  0
# random action: A + B
# reward:  0
# random action: Up
# reward:  0
# random action: Left
# reward:  0
# reward: 0.03333333333333333
# random action: Up
# reward:  0
# random action: Right + B
# reward:  0
# reward: 0.03333333333333333
# random action: Right + B
# reward:  2
# reward: 0.1
# random action: Right + A
# reward:  2
# reward: 0.13333333333333333
# random action: Left + A + B
# reward:  2
# reward: 0.16666666666666666
# random action: Left + A + B
# reward:  2
# reward: 0.13333333333333333
# random action: Left + B
# reward:  1
# reward: 0.1
# random action: A
# reward:  1
# reward: 0.06666666666666667
# random action: Right + A + B
# reward:  2
# reward: 0.1
# random action: Right + A + B
# reward:  2
# reward: 0.1
# random action: Right
# reward:  2
# reward: 0.16666666666666666
# random action: Left + A + B
# reward:  0
# reward: 0.1
# random action: Up
# reward:  0
# random action: Left + B
# reward:  -1
# random action: Right + A
# reward:  -1
# random action: Nope
# reward:  0
# random action: Nope
# reward:  0
# random action: Up
# reward:  0
# random action: Left + A + B
# reward:  -1
# random action: Left + A + B
# reward:  -1
# random action: Down
# reward:  -2
# random action: A
# reward:  -2
# random action: Right
# reward:  -2
# random action: A + B
# reward:  0
# random action: Down
# reward:  -1
# random action: A
# reward:  0
# random action: Nope
# reward:  0
# random action: A
# reward:  0
# random action: A + B
# reward:  0
# random action: Right + A
# reward:  1
# reward: 0.03333333333333333
# random action: Nope
# reward:  0
# random action: Nope
# reward:  0
# reward: 0.03333333333333333
# random action: Right + A
# reward:  0
# random action: Left + A + B
# reward:  1
# reward: 0.03333333333333333
# random action: Right + B
# reward:  0
# random action: A + B
# reward:  1
# reward: 0.03333333333333333
# random action: Left + A
# reward:  1
# reward: 0.03333333333333333
# random action: Left + B
# reward:  0
# random action: Down
# reward:  0
# random action: Down
# reward:  0
# random action: Right
# reward:  0
# random action: Left
# reward:  0
# random action: Left + A
# reward:  0
# random action: Right + A
# reward:  -1
# random action: Right
# reward:  0
# random action: Left + A + B
# reward:  0
# random action: Right + A
# reward:  0
# random action: Left + A
# reward:  0
# random action: Left + A
# reward:  0
# random action: Left + A
# reward:  -1
# random action: Nope
# reward:  -1
# random action: Right + A + B
# reward:  -1
# random action: Right + A + B
# reward:  0
# random action: A + B
# reward:  0
# random action: Left
# reward:  0
# random action: A + B
# reward:  0
# random action: Left + A + B
# reward:  0
# random action: Left + B
# reward:  0
# random action: Down
# reward:  0
# random action: Right + A + B
# reward:  1
# reward: 0.03333333333333333
# random action: Right + A
# reward:  1
# reward: 0.06666666666666667
# random action: Left + A
# reward:  1
# reward: 0.1
# random action: Down
# reward:  1
# reward: 0.06666666666666667
# random action: Left
# reward:  0
# reward: 0.03333333333333333
# random action: A + B
# reward:  0
# random action: Nope
# reward:  -1
# random action: Right + A
# reward:  1
# reward: 0.03333333333333333
# random action: Right + A
# reward:  1
# reward: 0.03333333333333333
# random action: Right + A + B
# reward:  2
# reward: 0.1
# random action: A
# reward:  2
# reward: 0.13333333333333333
# random action: Right + A + B
# reward:  2
# reward: 0.1
# random action: Right + A + B
# reward:  3
# reward: 0.2
# random action: Nope
# reward:  3
# reward: 0.2
# random action: A + B
# reward:  3
# reward: 0.16666666666666666
# random action: Nope
# reward:  0
# random action: Right
# reward:  0
# random action: Right + A
# reward:  1
# reward: 0.03333333333333333
# random action: Left + B
# reward:  -1
# random action: Down
# reward:  0
# random action: Right + A + B
# reward:  0
# random action: Up
# reward:  0
# random action: Right + A + B
# reward:  1
# reward: 0.03333333333333333
# random action: A
# reward:  0
# reward: 0.03333333333333333
# random action: Left + A + B
# reward:  0
# reward: 0.03333333333333333
# random action: Right + A
# reward:  1
# reward: 0.03333333333333333
# random action: Right
# reward:  2
# reward: 0.06666666666666667
# random action: Right + B
# reward:  3
# reward: 0.13333333333333333
# random action: A
# reward:  3
# reward: 0.16666666666666666
# random action: Left + B
# reward:  2
# reward: 0.13333333333333333
# random action: Nope
# reward:  1
# reward: 0.1
# random action: Right + A + B
# reward:  1
# reward: 0.06666666666666667
# random action: Right + A
# reward:  2
# reward: 0.13333333333333333
# random action: Right + A
# reward:  3
# reward: 0.2
# random action: Left + A
# reward:  3
# reward: 0.2
# random action: Left
# reward:  2
# reward: 0.13333333333333333
# random action: Left + B
# reward:  1
# reward: 0.1
# random action: A
# reward:  1
# reward: 0.03333333333333333
# random action: Nope
# reward:  1
# reward: 0.03333333333333333
# random action: Left + A + B
# reward:  0
# random action: Right + A + B
# reward:  -1
# random action: Left
# reward:  0
# random action: A + B
# reward:  -1
# random action: A + B
# reward:  -1
# random action: Right + A
# reward:  0
# random action: A
# reward:  0
# random action: Left + A + B
# reward:  0
# random action: Left + B
# reward:  -1
# random action: Down
# reward:  -1
# random action: Left + B
# reward:  -2
# random action: Nope
# reward:  -1
# random action: Down
# reward:  0
# random action: Right
# reward:  1
# reward: 0.03333333333333333
# random action: Right + B
# reward:  1
# reward: 0.03333333333333333
# random action: A
# reward:  1
# reward: 0.1
# random action: Left + B
# reward:  1
# reward: 0.06666666666666667
# random action: Left
# reward:  1
# reward: 0.06666666666666667
# random action: A + B
# reward:  0
# random action: Left + A + B
# reward:  0
# reward: 0.03333333333333333
# output: Nope predicted: Variable containing:
#
# Columns 0 to 9
#  0.1124  0.1096 -0.0365 -0.0074 -0.0997 -0.0397  0.0062  0.0870  0.0449 -0.0361
#
# Columns 10 to 12
# -0.0052 -0.1469 -0.1121
# [torch.cuda.FloatTensor of size 1x13 (GPU 0)]
#
# reward:  0
# random action: Left + B
# reward:  0
# random action: Left
# reward:  0
# random action: Down
# reward:  0
# random action: A
# reward:  0
# random action: Right + A
# reward:  1
# reward: 0.03333333333333333
# random action: A + B
# reward:  0
# reward: 0.03333333333333333
# random action: Right + A + B
# reward:  2
# reward: 0.1
# random action: Up
# reward:  2
# reward: 0.13333333333333333
# random action: Left + A + B
# reward:  2
# reward: 0.1
# random action: Nope
# reward:  0
# reward: 0.03333333333333333
# random action: Right + A + B
# reward:  2
# reward: 0.1
# random action: Right
# reward:  2
# reward: 0.13333333333333333
# random action: Right + A
# reward:  4
# reward: 0.23333333333333334
# random action: A
# reward:  3
# reward: 0.2
# random action: Left + A
# reward:  3
# reward: 0.23333333333333334
# random action: Down
# reward:  2
# reward: 0.16666666666666666
# random action: Left
# reward:  3
# reward: 0.2
# random action: Left + A
# reward:  2
# reward: 0.13333333333333333
# random action: Left + B
# reward:  2
# reward: 0.13333333333333333
# random action: Right + B
# reward:  2
# reward: 0.1
# random action: Left + A + B
# reward:  2
# reward: 0.1
# random action: Right + B
# reward:  0
# random action: A + B
# reward:  1
# reward: 0.06666666666666667
# random action: Right + A + B
# reward:  1
# reward: 0.06666666666666667
# random action: Left
# reward:  1
# reward: 0.06666666666666667
# random action: Down
# reward:  0
# reward: 0.03333333333333333
# random action: Right + B
# reward:  1
# reward: 0.06666666666666667
# random action: Right + A + B
# reward:  2
# reward: 0.1
# random action: Left + B
# reward:  0
# reward: 0.06666666666666667
# random action: Left + A
# reward:  -1
# random action: Left + A
# reward:  -1
# random action: Left
# reward:  -2
# random action: Left + A
# reward:  -2
# random action: A
# reward:  -3
# random action: Nope
# reward:  -3
# random action: Right
# reward:  -2
# random action: Left + B
# reward:  -2
# random action: Right
# reward:  -3
# random action: Left + A
# reward:  -2
# random action: Up
# reward:  -3
# random action: Down
# reward:  -3
# random action: Left + A + B
# reward:  -3
# random action: Nope
# reward:  -3
# random action: Up
# reward:  -3
# random action: Left + A + B
# reward:  -3
# random action: A
# reward:  0
# random action: Left + A
# reward:  0
# random action: Left + A
# reward:  -2
# random action: Left
# reward:  -3
# random action: Right + B
# reward:  -2
# random action: Right + B
# reward:  0
# random action: Right + B
# reward:  0
# random action: A + B
# reward:  0
# random action: Right + A + B
# reward:  0
# random action: Left + A
# reward:  0
# reward: 0.03333333333333333
# random action: Right + B
# reward:  0
# random action: Left + B
# reward:  0
# reward: 0.03333333333333333
# random action: A + B
# reward:  0
# random action: Right
# reward:  0
# random action: Left + A
# reward:  0
# reward: 0.03333333333333333
# random action: A + B
# reward:  0
# random action: Left + A
# reward:  -1
# random action: Nope
# reward:  0
# random action: Right + B
# reward:  0
# random action: Right + A + B
# reward:  1
# reward: 0.06666666666666667
# random action: A
# reward:  2
# reward: 0.1
# random action: Right + B
# reward:  1
# reward: 0.06666666666666667
# random action: Left + A
# reward:  2
# reward: 0.13333333333333333
# random action: Nope
# reward:  1
# reward: 0.06666666666666667
# random action: Nope
# reward:  2
# reward: 0.1
# random action: Down
# reward:  1
# reward: 0.06666666666666667
# random action: Up
# reward:  2
# reward: 0.1
# random action: A
# reward:  1
# reward: 0.06666666666666667
# random action: Left
# reward:  0
# random action: Right
# reward:  0
# random action: Right + B
# reward:  1
# reward: 0.06666666666666667
# random action: A + B
# reward:  1
# reward: 0.06666666666666667
# random action: Right + B
# reward:  2
# reward: 0.13333333333333333
# random action: Nope
# reward:  2
# reward: 0.1
# random action: A + B
# reward:  2
# reward: 0.13333333333333333
# random action: Nope
# reward:  2
# reward: 0.13333333333333333
# random action: Left + B
# reward:  1
# reward: 0.1
# random action: Right
# reward:  0
# random action: Right + A
# reward:  1
# reward: 0.06666666666666667
# random action: Right
# reward:  1
# reward: 0.06666666666666667
# random action: Left
# reward:  1
# reward: 0.1
# random action: Left + A
# reward:  0
# reward: 0.03333333333333333
# random action: Up
# reward:  0
# reward: 0.03333333333333333
# random action: Down
# reward:  0
# reward: 0.03333333333333333
# random action: Right
# reward:  0
# random action: Right + B
# reward:  1
# reward: 0.06666666666666667
# random action: Left + A + B
# reward:  1
# reward: 0.06666666666666667
# random action: Left + A + B
# reward:  1
# reward: 0.06666666666666667
# random action: Up
# reward:  0
# random action: Nope
# reward:  0
# reward: 0.03333333333333333
# random action: Left + A + B
# reward:  0
# random action: Left + B
# reward:  -1
# random action: Right + B
# reward:  0
# random action: Right + B
# reward:  1
# reward: 0.06666666666666667
# random action: Right + B
# reward:  2
# reward: 0.1
# random action: Right + B
# reward:  3
# reward: 0.16666666666666666
# random action: Right
# reward:  4
# reward: 0.23333333333333334
# random action: Nope
# reward:  3
# reward: 0.23333333333333334
# random action: A + B
# reward:  4
# reward: 0.23333333333333334
# random action: Right + A + B
# reward:  4
# reward: 0.23333333333333334
# random action: Up
# reward:  4
# reward: 0.23333333333333334
# random action: A + B
# reward:  4
# reward: 0.23333333333333334
# random action: Left + B
# reward:  3
# reward: 0.2
# random action: Down
# reward:  3
# reward: 0.2
# random action: A + B
# reward:  1
# reward: 0.13333333333333333
# random action: Left + A + B
# reward:  -1
# random action: Left + A + B
# reward:  -1
# random action: Up
# reward:  -2
# random action: Down
# reward:  0
# random action: Right + A + B
# reward:  1
# reward: 0.03333333333333333
# random action: Nope
# reward:  1
# reward: 0.06666666666666667
# random action: Left + B
# reward:  1
# reward: 0.03333333333333333
# random action: Up
# reward:  0
# random action: A + B
# reward:  0
# random action: A
# reward:  0
# random action: Left + A + B
# reward:  -1
# random action: Up
# reward:  0
# random action: Right + A
# reward:  0
# random action: Right
# reward:  2
# reward: 0.1
# random action: Right + B
# reward:  0
# reward: 0.06666666666666667
# random action: Left + B
# reward:  0
# random action: Left + A + B
# reward:  -1
# random action: Right
# reward:  0
# random action: Left + A
# reward:  0
# random action: Down
# reward:  0
# random action: Right + A
# reward:  0
# random action: Right + B
# reward:  1
# reward: 0.06666666666666667
# random action: Up
# reward:  0
# random action: A
# reward:  0
# random action: Left
# reward:  0
# random action: Down
# reward:  0
# random action: Right + A
# reward:  0
# random action: Left + A + B
# reward:  0
# reward: 0.03333333333333333
# random action: Left + A + B
# reward:  0
# random action: Up
# reward:  0
# random action: Right + A
# reward:  0
# random action: Down
# reward:  -1
# random action: Right
# reward:  1
# reward: 0.03333333333333333
# random action: Left + B
# reward:  0
# random action: Left + A
# reward:  -1
# random action: Left + A
# reward:  -1
# random action: Left + A + B
# reward:  -1
# random action: Down
# reward:  -2
# random action: Left + B
# reward:  -2
# random action: Right
# reward:  -2
# random action: A + B
# reward:  -2
# random action: A + B
# reward:  -2
# random action: Left + A
# reward:  -2
# random action: Left + A
# reward:  -3
# random action: Right + A + B
# reward:  -3
# random action: Right + B
# reward:  -1
# random action: Right
# reward:  1
# reward: 0.06666666666666667
# random action: Left + A + B
# reward:  1
# reward: 0.06666666666666667
# random action: A
# reward:  1
# reward: 0.03333333333333333
# random action: Left + A
# reward:  0
# reward: 0.03333333333333333
# random action: Left + B
# reward:  0
# random action: Right
# reward:  0
# random action: Right + A
# reward:  0
# reward: 0.03333333333333333
# random action: Left
# reward:  1
# reward: 0.06666666666666667
# random action: Left + A
# reward:  0
# random action: Left + A + B
# reward:  -1
# random action: Right + B
# reward:  0
# random action: Down
# reward:  0
# reward: 0.03333333333333333
# random action: Right + A
# reward:  0
# random action: Right + B
# reward:  1
# reward: 0.03333333333333333
# random action: A + B
# reward:  1
# reward: 0.06666666666666667
# random action: Left + B
# reward:  1
# reward: 0.06666666666666667
# random action: Left + A
# reward:  1
# reward: 0.03333333333333333
# random action: Left
# reward:  0
# random action: Left + A + B
# reward:  -1
# random action: Left + A
# reward:  -1
# random action: Right + A + B
# reward:  -1
# random action: Up
# reward:  -1
# random action: A + B
# reward:  -2
# random action: Left
# reward:  -1
# random action: Left + B
# reward:  -2
# random action: Left + A
# reward:  -2
# random action: A + B
# reward:  -2
# random action: Right
# reward:  -2
# random action: Right + A
# reward:  1
# reward: 0.03333333333333333
# random action: Left + B
# reward:  0
# reward: 0.03333333333333333
# random action: Right + B
# reward:  1
# reward: 0.03333333333333333
# random action: Left + B
# reward:  0
# reward: 0.03333333333333333
# random action: Down
# reward:  0
# random action: Up
# reward:  0
# reward: 0.03333333333333333
# random action: Up
# reward:  0
# random action: Up
# reward:  0
# random action: Left + B
# reward:  -1
# random action: Left + A + B
# reward:  -1
# random action: Right + B
# reward:  -1
# random action: Right + A
# reward:  -1
# random action: Right + A + B
# reward:  0
# random action: A
# reward:  0
# random action: Right + B
# reward:  1
# reward: 0.03333333333333333
# random action: Left + A + B
# reward:  1
# reward: 0.1
# random action: Right + A
# reward:  1
# reward: 0.03333333333333333
# random action: Nope
# reward:  1
# reward: 0.1
# random action: Nope
# reward:  1
# reward: 0.06666666666666667
# random action: Left + B
# reward:  1
# reward: 0.1
# random action: Right + B
# reward:  1
# reward: 0.03333333333333333
# random action: Right
# reward:  1
# reward: 0.1
# random action: Left + B
# reward:  1
# reward: 0.1
# random action: Left + B
# reward:  -1
# random action: Right
# reward:  1
# random action: Left
# reward:  -1
# random action: Right + A
# reward:  -1
# random action: Left + A + B
# reward:  -1
# random action: A + B
# reward:  -1
# random action: Left
# reward:  -1
# random action: Right
# reward:  -1
# random action: Right
# reward:  -1
# random action: Left + A + B
# reward:  -1
# random action: Left + A
# reward:  -1
# random action: Right
# reward:  1
# random action: Up
# reward:  0
# random action: Right + A + B
# reward:  0
# random action: Left + A + B
# reward:  0
# reward: 0.03333333333333333
# random action: Right
# reward:  0
# random action: Down
# reward:  0
# reward: 0.03333333333333333
# random action: Left + B
# reward:  0
# reward: 0.03333333333333333
# random action: Left + A + B
# reward:  -1
# random action: A + B
# reward:  -1
# random action: Left + B
# reward:  0
# random action: Left
# reward:  -2
# random action: Up
# reward:  -1
# random action: A + B
# reward:  0
# random action: Right + A + B
# reward:  0
# random action: Down
# reward:  1
# reward: 0.06666666666666667
# random action: Right + B
# reward:  2
# reward: 0.1
# random action: Nope
# reward:  2
# reward: 0.1
# random action: Down
# reward:  2
# reward: 0.13333333333333333
# random action: Left + A
# reward:  0
# reward: 0.06666666666666667
# random action: Right + B
# reward:  1
# reward: 0.03333333333333333
# random action: A
# reward:  1
# reward: 0.03333333333333333
# random action: Nope
# reward:  1
# reward: 0.06666666666666667
# random action: Right
# reward:  2
# reward: 0.06666666666666667
# random action: Right
# reward:  1
# reward: 0.06666666666666667
# random action: A
# reward:  2
# reward: 0.13333333333333333
# random action: Left + A + B
# reward:  0
# reward: 0.06666666666666667
# random action: A + B
# reward:  0
# random action: Down
# reward:  0
# random action: Left
# reward:  -1
# random action: Down
# reward:  0
# random action: Left + A
# reward:  0
# random action: Down
# reward:  0
# random action: Left + A + B
# reward:  -1
# random action: A + B
# reward:  -1
# random action: Up
# reward:  -1
# random action: Right + A
# reward:  1
# random action: Nope
# reward:  0
# random action: Right + B
# reward:  1
# reward: 0.03333333333333333
# random action: Right + A + B
# reward:  2
# reward: 0.06666666666666667
# random action: Right
# reward:  2
# reward: 0.1
# random action: Left + B
# reward:  1
# reward: 0.1
# random action: Left + A + B
# reward:  2
# reward: 0.1
# random action: Left + B
# reward:  1
# reward: 0.03333333333333333
# random action: Right
# reward:  1
# reward: 0.03333333333333333
# random action: A
# reward:  1
# reward: 0.06666666666666667
# random action: Right + A + B
# reward:  1
# reward: 0.06666666666666667
# random action: Up
# reward:  2
# reward: 0.1
# random action: Left
# reward:  1
# reward: 0.06666666666666667
# random action: Nope
# reward:  1
# reward: 0.06666666666666667
# random action: Left + B
# reward:  0
# reward: 0.03333333333333333
# random action: Right + A
# reward:  0
# reward: 0.03333333333333333
# random action: Right + B
# reward:  2
# reward: 0.1
# random action: Right
# reward:  3
# reward: 0.13333333333333333
# random action: Left + A + B
# reward:  3
# reward: 0.16666666666666666
# random action: A
# reward:  2
# reward: 0.13333333333333333
# random action: Right + A
# reward:  0
# random action: Down
# reward:  1
# reward: 0.03333333333333333
# random action: Right + B
# reward:  1
# reward: 0.03333333333333333
# random action: Down
# reward:  0
# reward: 0.03333333333333333
# random action: A
# reward:  0
# random action: A
# reward:  0
# random action: Right + A
# reward:  1
# reward: 0.03333333333333333
# random action: Left + A + B
# reward:  0
# random action: Left + A + B
# reward:  0
# random action: Left
# reward:  -2
# random action: A
# reward:  -2
# random action: A
# reward:  -2
# random action: Left + A
# reward:  -3
# random action: Left + A
# reward:  -3
# random action: Left
# reward:  -3
# random action: Down
# reward:  -3
# random action: A
# reward:  -3
# random action: Left + B
# reward:  -3
# random action: Left + B
# reward:  -3
# random action: Right + B
# reward:  -3
# random action: Up
# reward:  -3
# random action: A + B
# reward:  -3
# random action: Down
# reward:  -1
# random action: Left + A
# reward:  -1
# random action: A + B
# reward:  -1
# random action: Right + A
# reward:  -1
# random action: A + B
# reward:  0
# reward: 0.03333333333333333
# random action: Right
# reward:  0
# random action: Right + B
# reward:  1
# reward: 0.06666666666666667
# random action: Left + B
# reward:  1
# reward: 0.06666666666666667
# random action: Left + A + B
# reward:  1
# reward: 0.03333333333333333
# random action: Right
# reward:  0
# random action: Right
# reward:  1
# reward: 0.06666666666666667
# random action: Left
# reward:  0
# random action: Right + A + B
# reward:  -1
# random action: Up
# reward:  0
# random action: Left + B
# reward:  0
# random action: A
# reward:  -1
# random action: Right + A
# reward:  -1
# random action: A + B
# reward:  0
# random action: Left + A + B
# reward:  0
# random action: Down
# reward:  0
# random action: Left + B
# reward:  0
# random action: Right + A + B
# reward:  -1
# random action: Right + A + B
# reward:  0
# random action: A
# reward:  0
# random action: Left + A
# reward:  0
# random action: Left + A + B
# reward:  -1
# random action: Right
# reward:  0
# random action: Down
# reward:  0
# random action: A
# reward:  0
# random action: A
# reward:  0
# random action: Right + B
# reward:  0
# reward: 0.03333333333333333
# random action: Down
# reward:  0
# reward: 0.03333333333333333
# random action: Right + A
# reward:  0
# random action: Right
# reward:  1
# reward: 0.03333333333333333
# random action: Left
# reward:  1
# reward: 0.06666666666666667
# random action: Right + A + B
# reward:  1
# reward: 0.03333333333333333
# random action: Right + A + B
# reward:  2
# reward: 0.1
# random action: Left + A + B
# reward:  0
# reward: 0.03333333333333333
# random action: Down
# reward:  0
# random action: Up
# reward:  0
# random action: Right
# reward:  0
# random action: Right
# reward:  1
# reward: 0.03333333333333333
# random action: Left + A
# reward:  1
# reward: 0.06666666666666667
# random action: Left
# reward:  1
# reward: 0.03333333333333333
# random action: Up
# reward:  0
# random action: Nope
# reward:  0
# random action: Up
# reward:  0
# random action: Right + A
# reward:  0
# random action: Right + A + B
# reward:  1
# reward: 0.03333333333333333
# random action: Left + A + B
# reward:  0
# reward: 0.03333333333333333
# random action: A
# reward:  -1
# random action: Right + B
# reward:  0
# random action: Right
# reward:  2
# reward: 0.1
# random action: A
# reward:  2
# reward: 0.1
# random action: Left
# reward:  2
# reward: 0.1
# random action: Nope
# reward:  1
# reward: 0.06666666666666667
# random action: Right + A + B
# reward:  2
# reward: 0.1
# random action: A + B
# reward:  2
# reward: 0.1
# random action: Left
# reward:  0
# reward: 0.03333333333333333
# random action: Right + B
# reward:  0
# random action: Right + B
# reward:  2
# reward: 0.1
# random action: A + B
# reward:  2
# reward: 0.1
# random action: Left + B
# reward:  2
# reward: 0.1
# random action: Nope
# reward:  1
# reward: 0.06666666666666667
# random action: Left + B
# reward:  1
# reward: 0.06666666666666667
# random action: Right + B
# reward:  0
# reward: 0.03333333333333333
# random action: Right
# reward:  1
# reward: 0.1
# random action: Left + A + B
# reward:  1
# reward: 0.1
# random action: Left + A + B
# reward:  1
# reward: 0.06666666666666667
# random action: A
# reward:  1
# reward: 0.03333333333333333
# random action: Left + A + B
# reward:  0
# reward: 0.03333333333333333
# random action: A
# reward:  0
# random action: Right
# reward:  1
# reward: 0.03333333333333333
# random action: Left + A
# reward:  1
# reward: 0.03333333333333333
# random action: Up
# reward:  0
# random action: Left + B
# reward:  0
# random action: Nope
# reward:  0
# random action: Left
# reward:  -1
# random action: Left + A
# reward:  -1
# random action: Nope
# reward:  -1
# random action: Left + A + B
# reward:  -2
# random action: Up
# reward:  -2
# random action: A
# reward:  -2
# random action: Up
# reward:  -1
# random action: Right
# reward:  0
# random action: Right
# reward:  1
# reward: 0.06666666666666667
# random action: Left
# reward:  0
# random action: Left + A + B
# reward:  0
# random action: Left + A + B
# reward:  -1
# random action: Left + A
# reward:  -2
# random action: Left + A
# reward:  -3
# random action: Down
# reward:  -3
# random action: A + B
# reward:  -3
# random action: Up
# reward:  -3
# random action: Right
# reward:  -2
# random action: Right + A
# reward:  -2
# random action: A
# reward:  0
# random action: A
# reward:  0
# random action: Right + A + B
# reward:  0
# random action: A + B
# reward:  0
# reward: 0.03333333333333333
# random action: Down
# reward:  0
# random action: Right + B
# reward:  0
# random action: Right + A + B
# reward:  2
# reward: 0.1
# random action: Right + A + B
# reward:  2
# reward: 0.1
# random action: Right + A
# reward:  2
# reward: 0.13333333333333333
# random action: Right + A
# reward:  3
# reward: 0.16666666666666666
# random action: A + B
# reward:  3
# reward: 0.2
# random action: A
# reward:  2
# reward: 0.16666666666666666
# random action: Right
# reward:  4
# reward: 0.23333333333333334
# random action: A
# reward:  3
# reward: 0.2
# random action: Right + A
# reward:  3
# reward: 0.23333333333333334
# random action: Left
# reward:  3
# reward: 0.23333333333333334
# random action: Right
# reward:  3
# reward: 0.2
# random action: A + B
# reward:  3
# reward: 0.23333333333333334
# random action: Left
# reward:  3
# reward: 0.23333333333333334
# random action: Left + A + B
# reward:  2
# reward: 0.16666666666666666
# random action: Up
# reward:  0
# random action: A
# reward:  0
# random action: A
# reward:  0
# random action: Right + B
# reward:  0
# random action: Right + B
# reward:  0
# random action: Left + B
# reward:  0
# random action: Up
# reward:  0
# random action: Left + A + B
# reward:  0
# random action: Nope
# reward:  0
# random action: Left + A + B
# reward:  0
# random action: Up
# reward:  -1
# random action: Left + A + B
# reward:  -1
# random action: Up
# reward:  0
# random action: Left + A
# reward:  -1
# random action: Right + B
# reward:  0
# random action: Right
# reward:  0
# random action: Left + B
# reward:  0
# reward: 0.03333333333333333
# random action: Left + B
# reward:  0
# random action: Right + B
# reward:  0
# random action: Left + B
# reward:  0
# random action: Left
# reward:  -1
# random action: A + B
# reward:  -2
# random action: Right + A + B
# reward:  -1
# random action: Nope
# reward:  -2
# random action: Left + B
# reward:  -1
# random action: Left + A + B
# reward:  -2
# random action: Down
# reward:  -2
# random action: Left + A + B
# reward:  -3
# random action: A
# reward:  -3
# random action: Left + B
# reward:  -2
# random action: Left + B
# reward:  -4
# random action: A + B
# reward:  -4
# random action: Right + A
# reward:  -4
# random action: Right + A + B
# reward:  -3
# random action: Right + B
# reward:  0
# random action: Nope
# reward:  0
# random action: A
# reward:  0
# random action: Nope
# reward:  0
# random action: Down
# reward:  0
# random action: Left
# reward:  0
# random action: Right + A
# reward:  1
# reward: 0.03333333333333333
# random action: Down
# reward:  0
# reward: 0.03333333333333333
# random action: Left + A + B
# reward:  0
# reward: 0.03333333333333333
# random action: A + B
# reward:  0
# random action: Left
# reward:  0
# random action: Left
# reward:  -1
# random action: Left + A + B
# reward:  0
# random action: A
# reward:  0
# random action: Right + B
# reward:  1
# reward: 0.03333333333333333
# random action: Right + A
# reward:  1
# reward: 0.06666666666666667
# random action: Left + A
# reward:  1
# reward: 0.1
# random action: Right + B
# reward:  2
# reward: 0.1
# random action: Left + A + B
# reward:  1
# reward: 0.06666666666666667
# random action: Right
# reward:  0
# random action: Nope
# reward:  0
# reward: 0.03333333333333333
# random action: Right + A + B
# reward:  0
# reward: 0.03333333333333333
# random action: Right + B
# reward:  1
# reward: 0.06666666666666667
# random action: Up
# reward:  2
# reward: 0.1
# random action: Left + A
# reward:  1
# reward: 0.06666666666666667
# random action: A
# reward:  1
# reward: 0.03333333333333333
# random action: A + B
# reward:  0
# reward: 0.03333333333333333
# random action: Left + B
# reward:  -1
# random action: Down
# reward:  0
# random action: Nope
# reward:  0
# random action: A + B
# reward:  0
# random action: A
# reward:  0
# random action: Right + A
# reward:  0
# random action: Left + A
# reward:  0
# reward: 0.03333333333333333
# random action: Down
# reward:  0
# random action: Left + A + B
# reward:  0
# random action: Up
# reward:  -1
# random action: Right + A + B
# reward:  -1
# random action: Right + A + B
# reward:  1
# reward: 0.03333333333333333
# random action: Nope
# reward:  1
# reward: 0.03333333333333333
# random action: A
# reward:  0
# random action: Right + A
# reward:  0
# reward: 0.03333333333333333
# random action: Up
# reward:  1
# reward: 0.06666666666666667
# random action: Left
# reward:  1
# reward: 0.03333333333333333
# random action: Up
# reward:  0
# random action: A
# reward:  0
# reward: 0.03333333333333333
# random action: Left
# reward:  0
# random action: Down
# reward:  0
# random action: A + B
# reward:  0
# random action: Left + A + B
# reward:  -1
# random action: Right + B
# reward:  0
# random action: Down
# reward:  0
# random action: Right + A + B
# reward:  0
# random action: Down
# reward:  1
# reward: 0.06666666666666667
# random action: Right + A
# reward:  2
# reward: 0.1
# random action: Down
# reward:  1
# reward: 0.06666666666666667
# random action: Up
# reward:  0
# random action: Nope
# reward:  0
# random action: Right
# reward:  0
# random action: A + B
# reward:  0
# reward: 0.03333333333333333
# random action: Right + A + B
# reward:  1
# reward: 0.06666666666666667
# random action: Right + A
# reward:  1
# reward: 0.06666666666666667
# random action: Up
# reward:  1
# reward: 0.1
# random action: A + B
# reward:  1
# reward: 0.1
# random action: Right
# reward:  2
# reward: 0.13333333333333333
# random action: Left + A + B
# reward:  2
# reward: 0.1
# random action: Left + A
# reward:  1
# reward: 0.1
# random action: Left + A
# reward:  -1
# random action: A + B
# reward:  0
# random action: Right + A
# reward:  0
# random action: Left
# reward:  0
# random action: Left + A
# reward:  -1
# random action: Up
# reward:  -1
# random action: Right + A
# reward:  -1
# random action: A + B
# reward:  -1
# random action: Right + B
# reward:  -1
# random action: Right + B
# reward:  0
# reward: 0.03333333333333333
# random action: Nope
# reward:  1
# reward: 0.06666666666666667
# random action: Right + B
# reward:  1
# reward: 0.03333333333333333
# random action: Left + A + B
# reward:  1
# reward: 0.1
# random action: Right + B
# reward:  1
# reward: 0.06666666666666667
# random action: Right + B
# reward:  2
# reward: 0.1
# random action: Left
# reward:  1
# reward: 0.1
# random action: Left + B
# reward:  1
# reward: 0.1
# random action: Right + B
# reward:  1
# reward: 0.06666666666666667
# random action: A
# reward:  1
# reward: 0.1
# random action: Left
# reward:  1
# reward: 0.1
# random action: Right
# reward:  2
# reward: 0.1
# random action: Up
# reward:  2
# reward: 0.1
# random action: Down
# reward:  0
# reward: 0.06666666666666667
# random action: Right + A
# reward:  0
# random action: Right + A
# reward:  0
# random action: A + B
# reward:  0
# random action: Nope
# reward:  0
# random action: Left + A + B
# reward:  0
# random action: Left + A + B
# reward:  -2
# random action: Right + B
# reward:  -1
# random action: Down
# reward:  -1
# random action: Nope
# reward:  0
# random action: Right + A + B
# reward:  0
# random action: Down
# reward:  0
# random action: Left
# reward:  -1
# random action: Up
# reward:  0
# random action: Nope
# reward:  0
# random action: Nope
# reward:  0
# random action: Right + A + B
# reward:  1
# reward: 0.03333333333333333
# random action: Left + A
# reward:  1
# reward: 0.03333333333333333
# random action: A + B
# reward:  -1
# random action: A
# reward:  0
# random action: Right
# reward:  0
# random action: Right + A
# reward:  1
# reward: 0.06666666666666667
# random action: Left
# reward:  1
# reward: 0.1
# random action: Right
# reward:  1
# reward: 0.06666666666666667
# random action: Nope
# reward:  1
# reward: 0.1
# random action: Left + B
# reward:  -1
# random action: Left
# reward:  -1
# random action: Nope
# reward:  -2
# random action: Down
# reward:  0
# random action: Right
# reward:  0
# reward: 0.03333333333333333
# random action: Down
# reward:  0
# random action: Up
# reward:  0
# random action: Right + A
# reward:  0
# random action: A + B
# reward:  0
# reward: 0.03333333333333333
# random action: A + B
# reward:  0
# reward: 0.03333333333333333
# random action: Left + B
# reward:  0
# reward: 0.03333333333333333
# random action: Right + B
# reward:  0
# random action: Right + A
# reward:  1
# reward: 0.06666666666666667
# random action: A
# reward:  1
# reward: 0.06666666666666667
# random action: A
# reward:  0
# random action: Right
# reward:  0
# random action: Left + B
# reward:  0
# random action: Left
# reward:  -1
# random action: Left + A
# reward:  -2
# random action: Down
# reward:  -2
# random action: Right
# reward:  -2
# random action: Up
# reward:  -1
# random action: Left + A + B
# reward:  -2
# random action: Right + B
# reward:  -2
# random action: A + B
# reward:  -1
# random action: Right
# reward:  -1
# random action: A + B
# reward:  -1
# random action: Left + A
# reward:  -1
# random action: Right + A
# reward:  -1
# random action: Nope
# reward:  0
# random action: Up
# reward:  0
# random action: Right + B
# reward:  0
# random action: A + B
# reward:  1
# reward: 0.06666666666666667
# random action: Up
# reward:  1
# reward: 0.06666666666666667
# random action: A + B
# reward:  1
# reward: 0.06666666666666667
# random action: Left + A
# reward:  1
# reward: 0.03333333333333333
# random action: Right
# reward:  1
# reward: 0.03333333333333333
# random action: A + B
# reward:  0
# reward: 0.03333333333333333
# random action: A
# reward:  0
# random action: Left + B
# reward:  -1
# random action: Up
# reward:  0
# random action: Down
# reward:  0
# random action: Right + A
# reward:  1
# reward: 0.03333333333333333
# random action: Left + B
# reward:  1
# reward: 0.03333333333333333
# random action: Nope
# reward:  0
# random action: A + B
# reward:  0
# random action: Down
# reward:  0
# random action: Left + A
# reward:  -1
# random action: Up
# reward:  0
# random action: Left + A + B
# reward:  -1
# random action: Left + A
# reward:  -1
# random action: Nope
# reward:  -1
# random action: Up
# reward:  -1
# random action: Down
# reward:  -1
# random action: Up
# reward:  -1
# random action: Up
# reward:  0
# random action: Right + A + B
# reward:  0
# random action: Left + A
# reward:  0
# reward: 0.03333333333333333
# output: Nope predicted: Variable containing:
#
# Columns 0 to 9
#  0.1122  0.0770 -0.0199 -0.0309 -0.0800 -0.0598  0.0206  0.0976 -0.0076 -0.0264
#
# Columns 10 to 12
#  0.0285 -0.1533 -0.1403
# [torch.cuda.FloatTensor of size 1x13 (GPU 0)]
#
# reward:  0
# random action: Right + A + B
# reward:  0
# random action: A
# reward:  0
# reward: 0.03333333333333333
# random action: Nope
# reward:  1
# reward: 0.06666666666666667
# random action: A + B
# reward:  1
# reward: 0.03333333333333333
# random action: Left
# reward:  0
# random action: A
# reward:  -1
# random action: Left + B
# reward:  -1
# random action: Right
# reward:  -1
# random action: Right
# reward:  0
# random action: Right + B
# reward:  0
# random action: Nope
# reward:  0
# reward: 0.03333333333333333
# random action: Left + B
# reward:  0
# random action: Left + A
# reward:  -2
# random action: Right + A
# reward:  -1
# random action: A
# reward:  -1
# random action: Right + A
# reward:  -1
# random action: Down
# reward:  -1
# random action: Left + A
# reward:  -1
# random action: A + B
# reward:  -1
# random action: Right + B
# reward:  -1
# random action: A + B
# reward:  -1
# random action: Right + B
# reward:  1
# reward: 0.03333333333333333
# random action: Right + B
# reward:  2
# reward: 0.06666666666666667
# random action: Nope
# reward:  2
# reward: 0.1
# random action: Left
# reward:  0
# random action: Down
# reward:  0
# random action: Right + A + B
# reward:  1
# reward: 0.03333333333333333
# random action: Down
# reward:  0
# reward: 0.03333333333333333
# random action: Right + B
# reward:  2
# reward: 0.1
# random action: Right + A
# reward:  2
# reward: 0.13333333333333333
# random action: Up
# reward:  3
# reward: 0.2
# random action: A + B
# reward:  3
# reward: 0.2
# random action: A
# reward:  1
# reward: 0.1
# random action: Nope
# reward:  1
# reward: 0.06666666666666667
# random action: Up
# reward:  0
# random action: A + B
# reward:  0
# random action: Nope
# reward:  0
# random action: Right + A + B
# reward:  0
# random action: Nope
# reward:  1
# reward: 0.06666666666666667
# random action: Left + A
# reward:  0
# reward: 0.03333333333333333
# random action: Left + A + B
# reward:  -1
# random action: Down
# reward:  0
# random action: Down
# reward:  0
# random action: Right + B
# reward:  0
# random action: Left + B
# reward:  0
# random action: Left
# reward:  -1
# random action: A
# reward:  -2
# random action: Right + B
# reward:  -1
# random action: A + B
# reward:  -2
# random action: Left + A
# reward:  -1
# random action: A + B
# reward:  -2
# random action: Right + A
# reward:  0
# random action: A + B
# reward:  0
# random action: Nope
# reward:  0
# random action: Down
# reward:  0
# random action: A + B
# reward:  0
# random action: Down
# reward:  0
# random action: A + B
# reward:  0
# random action: Right
# reward:  0
# random action: Right + A
# reward:  1
# reward: 0.06666666666666667
# random action: Nope
# reward:  1
# reward: 0.06666666666666667
# random action: Left + A
# reward:  0
# random action: Up
# reward:  0
# reward: 0.03333333333333333
# random action: Left + A + B
# reward:  -1
# random action: Left + A
# reward:  -2
# random action: Left + A
# reward:  -3
# random action: A + B
# reward:  -2
# random action: Left
# reward:  -3
# random action: Left + A
# reward:  -3
# random action: Right + A + B
# reward:  -3
# random action: Right + B
# reward:  -2
# random action: Left + A
# reward:  -3
# random action: Left
# reward:  -3
# random action: Right + A
# reward:  1
# random action: Left + A + B
# reward:  0
# reward: 0.03333333333333333
# random action: Right + B
# reward:  0
# random action: Down
# reward:  0
# random action: Right + B
# reward:  1
# reward: 0.03333333333333333
# random action: Left + A
# reward:  0
# reward: 0.03333333333333333
# random action: A
# reward:  0
# reward: 0.03333333333333333
# random action: Left + A + B
# reward:  0
# random action: Right
# reward:  1
# reward: 0.03333333333333333
# random action: Left + A + B
# reward:  0
# random action: Down
# reward:  0
# random action: Up
# reward:  0
# random action: Right + A
# reward:  1
# reward: 0.03333333333333333
# random action: Left + A + B
# reward:  -1
# random action: Right + A + B
# reward:  0
# random action: Left + A
# reward:  -1
# random action: Right + B
# reward:  0
# random action: A
# reward:  1
# reward: 0.06666666666666667
# random action: Right + A + B
# reward:  1
# reward: 0.06666666666666667
# random action: A
# reward:  1
# reward: 0.06666666666666667
# random action: Down
# reward:  2
# reward: 0.1
# random action: Left + A + B
# reward:  1
# reward: 0.06666666666666667
# random action: Down
# reward:  1
# reward: 0.03333333333333333
# random action: Left + B
# reward:  0
# reward: 0.03333333333333333
# random action: Down
# reward:  0
# reward: 0.03333333333333333
# random action: Right
# reward:  0
# random action: Nope
# reward:  0
# reward: 0.03333333333333333
# random action: Left
# reward:  -1
# random action: Right
# reward:  1
# reward: 0.03333333333333333
# random action: Left + B
# reward:  -1
# random action: Up
# reward:  0
# random action: Right + A
# reward:  0
# random action: A
# reward:  1
# reward: 0.06666666666666667
# random action: Right + A + B
# reward:  2
# reward: 0.1
# random action: Right + B
# reward:  2
# reward: 0.13333333333333333
# random action: Nope
# reward:  3
# reward: 0.2
# random action: Left
# reward:  2
# reward: 0.16666666666666666
# random action: Up
# ...
# random action: A
# reward:  -2
# random action: Right + B
# reward:  -1
# random action: Down
# reward:  0
# random action: A + B
# reward:  0
# random action: Down
# reward:  0
# random action: Nope
# reward:  0
# random action: Nope
# reward:  0
# random action: Right + B
# reward:  0
# reward: 0.03333333333333333
# random action: Left + A + B
# reward:  0
# random action: Left + A + B
# reward:  -1
# random action: Right
# reward:  1
# random action: A + B
# reward:  0
# reward: 0.03333333333333333
# random action: Right + A + B
# reward:  1
# reward: 0.06666666666666667
# random action: Down
# reward:  2
# reward: 0.1
# random action: Left + A + B
# reward:  1
# reward: 0.06666666666666667
# random action: Left
# reward:  0
# reward: 0.03333333333333333
# random action: Right
# reward:  1
# reward: 0.03333333333333333
# random action: Nope
# reward:  0
# reward: 0.03333333333333333
# random action: Right + A
# reward:  1
# reward: 0.06666666666666667
# random action: Nope
# reward:  1
# reward: 0.06666666666666667
# random action: Down
# reward:  1
# reward: 0.06666666666666667
# random action: Up
# reward:  1
# reward: 0.06666666666666667
# random action: Nope
# reward:  1
# reward: 0.06666666666666667
# random action: Down
# reward:  0
# reward: 0.03333333333333333
# random action: A
# reward:  0
# random action: A
# reward:  0
# random action: Up
# reward:  0
# random action: Up
# reward:  0
# random action: Left + B
# reward:  -1
# random action: Left + A
# reward:  -1
# random action: Left
# reward:  -3
# random action: Right + B
# reward:  -2
# random action: A + B
# reward:  -2
# random action: Left + A + B
# reward:  -2
# random action: Left
# reward:  -4
# random action: Down
# reward:  0
# random action: Down
# reward:  0
# random action: Right + A
# reward:  1
# reward: 0.03333333333333333
# random action: Left + B
# reward:  0
# random action: Nope
# reward:  0
# random action: A + B
# reward:  0
# random action: Right + A + B
# reward:  0
# random action: Left + A + B
# reward:  0
# reward: 0.03333333333333333
# random action: Right + A + B
# reward:  1
# reward: 0.03333333333333333
# random action: Right + A
# reward:  2
# reward: 0.06666666666666667
# random action: Left
# reward:  1
# reward: 0.06666666666666667
# random action: Right
# reward:  1
# reward: 0.06666666666666667
# random action: Nope
# reward:  1
# reward: 0.1
# random action: Left
# reward:  1
# reward: 0.1
# random action: Right + A
# reward:  1
# reward: 0.06666666666666667
# random action: Down
# reward:  0
# reward: 0.03333333333333333
# random action: A
# reward:  0
# random action: A + B
# reward:  0
# random action: A + B
# reward:  0
# random action: Down
# reward:  0
# random action: Left + A
# reward:  0
# random action: Right + A
# reward:  0
# random action: Left
# reward:  0
# random action: Right + B
# reward:  0
# random action: Down
# reward:  0
# random action: A + B
# reward:  0
# random action: Right
# reward:  1
# reward: 0.03333333333333333
# random action: Nope
# reward:  1
# reward: 0.03333333333333333
# random action: A + B
# reward:  1
# reward: 0.03333333333333333
# random action: Left + A + B
# reward:  0
# random action: Right + A
# reward:  1
# reward: 0.03333333333333333
# random action: Nope
# reward:  0
# random action: Right + A + B
# reward:  1
# reward: 0.03333333333333333
# random action: Left + A + B
# reward:  0
# random action: Left + B
# reward:  0
# random action: Left
# reward:  -2
# random action: Right + B
# reward:  -1
# random action: Left
# reward:  -1
# random action: Left + A
# reward:  -3
# random action: Right + A
# reward:  -3
# random action: A
# reward:  -2
# random action: Left + A + B
# reward:  0
# random action: Right + A + B
# reward:  0
# random action: A
# reward:  0
# reward: 0.03333333333333333
# random action: Left
# reward:  0
# random action: Left
# reward:  0
# random action: Left + A + B
# reward:  0
# random action: Down
# reward:  0
# random action: Left + B
# reward:  0
# random action: Left + A + B
# reward:  0
# random action: Right + A
# reward:  1
# reward: 0.03333333333333333
# random action: Left
# reward:  -1
# random action: Left
# reward:  -1
# random action: Right
# reward:  1
# reward: 0.03333333333333333
# random action: Nope
# reward:  0
# random action: Right
# reward:  1
# reward: 0.03333333333333333
# random action: A
# reward:  1
# reward: 0.03333333333333333
# random action: Left + B
# reward:  0
# random action: A
# reward:  0
# random action: Right
# reward:  1
# reward: 0.03333333333333333
# random action: Left
# reward:  0
# random action: Left
# reward:  0
# random action: A + B
# reward:  0
# random action: Right + A
# reward:  0
# random action: Down
# reward:  -1
# random action: Right + B
# reward:  1
# reward: 0.03333333333333333
# random action: Left
# reward:  0
# random action: Right + A + B
# reward:  0
# random action: A + B
# reward:  1
# reward: 0.03333333333333333
# random action: Right + A
# reward:  0
# random action: Right + A
# reward:  0
# reward: 0.03333333333333333
# random action: Right + B
# reward:  2
# reward: 0.1
# random action: Right + A + B
# reward:  2
# reward: 0.13333333333333333
# random action: Right + B
# reward:  3
# reward: 0.16666666666666666
# random action: Down
# reward:  3
# reward: 0.2
# random action: Left + A
# reward:  2
# reward: 0.16666666666666666
# random action: Left
# reward:  2
# reward: 0.16666666666666666
# random action: Left + A + B
# reward:  2
# reward: 0.1
# random action: Right
# reward:  0
# random action: Down
# reward:  0
# random action: Right + A + B
# reward:  0
# reward: 0.03333333333333333
# random action: Left + B
# reward:  0
# random action: Up
# reward:  0
# random action: Right + B
# reward:  0
# reward: 0.03333333333333333
# random action: Down
# reward:  1
# reward: 0.03333333333333333
# random action: Left + B
# reward:  0
# random action: Left + A
# reward:  -1
# random action: Right + A + B
# reward:  0
# random action: Right + B
# reward:  0
# random action: Right + A + B
# reward:  0
# random action: Right + A + B
# reward:  1
# reward: 0.06666666666666667
# random action: Right + A + B
# reward:  2
# reward: 0.13333333333333333
# random action: Left + B
# reward:  2
# reward: 0.13333333333333333
# random action: Right + B
# reward:  3
# reward: 0.16666666666666666
# random action: Right + A + B
# reward:  3
# reward: 0.16666666666666666
# random action: Left + A
# reward:  3
# reward: 0.23333333333333334
# random action: A + B
# reward:  3
# reward: 0.16666666666666666
# random action: Nope
# reward:  3
# reward: 0.2
# random action: Right + A + B
# reward:  3
# reward: 0.16666666666666666
# random action: Right + A + B
# reward:  -1
# reward: 0.06666666666666667
# random action: Down
# reward:  0
# random action: Right
# reward:  0
# random action: Down
# reward:  0
# random action: Down
# reward:  0
# random action: Up
# reward:  0
# random action: Down
# reward:  0
# random action: Right + A + B
# reward:  0
# random action: Left + A
# reward:  0
# random action: Left + A + B
# reward:  -1
# random action: Right + B
# reward:  -1
# random action: Right + A + B
# reward:  0
# random action: Right
# reward:  1
# reward: 0.03333333333333333
# random action: Right + B
# reward:  1
# reward: 0.06666666666666667
# random action: Right
# reward:  0
# reward: 0.03333333333333333
# random action: Left + A + B
# reward:  0
# random action: Left + B
# reward:  -1
# random action: Right + A
# reward:  -1
# random action: Left + B
# reward:  -1
# random action: Right + B
# reward:  -1
# random action: A + B
# reward:  0
# random action: Right
# reward:  0
# reward: 0.03333333333333333
# random action: A + B
# reward:  1
# reward: 0.03333333333333333
# random action: Down
# reward:  1
# reward: 0.03333333333333333
# random action: Left
# reward:  0
# random action: Nope
# reward:  0
# random action: Right
# reward:  0
# reward: 0.03333333333333333
# random action: Left + A
# reward:  0
# random action: Left + A
# reward:  -1
# random action: Right + A + B
# reward:  0
# random action: Right + A + B
# reward:  1
# reward: 0.06666666666666667
# random action: Up
# reward:  0
# reward: 0.06666666666666667
# random action: Right + A
# reward:  0
# random action: Left + A + B
# reward:  1
# reward: 0.03333333333333333
# random action: Right + A
# reward:  0
# random action: Left + B
# reward:  0
# random action: Up
# reward:  0
# random action: Right + A + B
# reward:  0
# random action: Right + A + B
# reward:  1
# reward: 0.03333333333333333
# random action: Left + A + B
# reward:  -1
# random action: Left + A + B
# reward:  -1
# random action: Up
# reward:  0
# random action: Left + A + B
# reward:  -1
# random action: Right + A + B
# reward:  0
# random action: Left + A + B
# reward:  -1
# random action: Nope
# reward:  -1
# random action: Up
# reward:  -1
# random action: A + B
# reward:  -1
# random action: A
# reward:  -1
# random action: Left + A
# reward:  -1
# random action: A + B
# reward:  0
# random action: Left + A + B
# reward:  0
# random action: Right + A
# reward:  1
# random action: Right + A
# reward:  2
# reward: 0.06666666666666667
# random action: Right
# reward:  3
# reward: 0.13333333333333333
# random action: Left + B
# reward:  1
# reward: 0.1
# random action: Right + B
# reward:  2
# reward: 0.13333333333333333
# random action: Left + A
# reward:  0
# random action: Right + B
# reward:  0
# random action: Down
# reward:  0
# random action: A + B
# reward:  0
# random action: A
# reward:  1
# reward: 0.03333333333333333
# random action: Right + A
# reward:  0
# random action: A
# reward:  0
# random action: Left + A
# reward:  -1
# random action: Right + A + B
# reward:  1
# reward: 0.03333333333333333
# random action: Right + B
# reward:  0
# random action: Left + A
# reward:  0
# random action: A + B
# reward:  -1
# random action: Down
# reward:  0
# random action: Nope
# reward:  0
# random action: Right + A
# reward:  0
# random action: Left + A + B
# reward:  0
# random action: A + B
# reward:  0
# random action: Right
# reward:  0
# random action: A + B
# reward:  0
# reward: 0.03333333333333333
# random action: Right + A + B
# reward:  0
# reward: 0.03333333333333333
# random action: Left
# reward:  -1
# random action: Right + A
# reward:  0
# random action: Right
# reward:  1
# reward: 0.03333333333333333
# random action: A
# reward:  1
# reward: 0.03333333333333333
# random action: Right + A + B
# reward:  0
# random action: Right + A + B
# reward:  0
# random action: Right + B
# reward:  0
# random action: Nope
# reward:  0
# random action: Down
# reward:  0
# random action: Down
# reward:  0
# random action: Right + A + B
# reward:  0
# random action: Right + B
# reward:  0
# random action: Left + A + B
# reward:  0
# random action: Left + B
# reward:  -1
# random action: Right + A
# reward:  -1
# random action: Right + A
# reward:  0
# random action: Right
# reward:  1
# reward: 0.06666666666666667
# random action: Right
# reward:  1
# reward: 0.06666666666666667
# random action: Left + A
# reward:  -1
# random action: Down
# reward:  0
# random action: Right + B
# reward:  0
# random action: A
# reward:  0
# random action: Down
# reward:  0
# random action: Up
# reward:  0
# random action: Up
# reward:  0
# random action: A + B
# reward:  0
# random action: Left + A
# reward:  0
# random action: Nope
# reward:  -1
# random action: Right
# reward:  0
# random action: Left
# reward:  0
# random action: Right + A
# reward:  0
# random action: Right + B
# reward:  0
# reward: 0.03333333333333333
# random action: Right + A + B
# reward:  1
# reward: 0.06666666666666667
# random action: Nope
# reward:  1
# reward: 0.1
# random action: Right + A
# reward:  0
# reward: 0.03333333333333333
# random action: Left + A + B
# reward:  0
# random action: A
# reward:  0
# random action: Right + A + B
# reward:  1
# random action: Down
# reward:  0
# random action: A + B
# reward:  0
# random action: Left
# reward:  -1
# random action: A
# reward:  0
# random action: Right + A
# reward:  0
# random action: Nope
# reward:  0
# random action: A + B
# reward:  0
# random action: Right + A + B
# reward:  1
# reward: 0.03333333333333333
# random action: Right + A
# reward:  2
# reward: 0.06666666666666667
# random action: Right
# reward:  0
# reward: 0.03333333333333333
# random action: Left + B
# reward:  -1
# random action: Down
# reward:  0
# random action: Left
# reward:  -1
# random action: A + B
# reward:  0
# random action: Right + B
# reward:  -1
# random action: Right
# reward:  0
# random action: Up
# reward:  0
# random action: Right + A
# reward:  1
# reward: 0.03333333333333333
# random action: Right + A
# reward:  2
# reward: 0.1
# random action: Left + A
# reward:  -1
# random action: Left + A + B
# reward:  -1
# random action: A
# reward:  -1
# random action: A + B
# reward:  0
# random action: Left + A
# reward:  -1
# random action: Right + A + B
# reward:  0
# random action: Left + A + B
# reward:  -1
# random action: Down
# reward:  0
# random action: Left
# reward:  -1
# random action: Left
# reward:  -1
# random action: Left + A + B
# reward:  -2
# random action: Up
# reward:  -2
# random action: Up
# reward:  -2
# random action: Up
# reward:  -2
# random action: Right + A
# reward:  -1
# random action: Left + A
# reward:  -2
# random action: Nope
# reward:  -1
# random action: Right
# reward:  0
# random action: Left + B
# reward:  -1
# random action: Nope
# reward:  0
# random action: Right + B
# reward:  0
# random action: Nope
# reward:  0
# reward: 0.03333333333333333
# random action: Up
# reward:  0
# random action: Left + A
# reward:  0
# random action: Left + A
# reward:  -2
# random action: Left + A + B
# reward:  -2
# random action: A + B
# reward:  -3
# random action: Left
# reward:  -4
# random action: Left + A
# reward:  -4
# random action: A
# reward:  -4
# random action: Left + A
# reward:  -4
# random action: Right
# reward:  0
# random action: Down
# 1th:
# reward:  0
# last reward:  -1.0
# Loss: 3.116,  l_rate: 0.000100
# Loss: 0.096,  l_rate: 0.000100
# Loss: 0.003,  l_rate: 0.000100
# Loss: 0.004,  l_rate: 0.000100
# Loss: 0.002,  l_rate: 0.000100
# Loss: 36.456,  l_rate: 0.000100
# Loss: 0.037,  l_rate: 0.000100
# Loss: 0.003,  l_rate: 0.000100
# Loss: 0.048,  l_rate: 0.000100
# Loss: 0.002,  l_rate: 0.000100
# Loss: 0.001,  l_rate: 0.000100
# Loss: 0.005,  l_rate: 0.000100
# Loss: 0.004,  l_rate: 0.000100
# Loss: 0.002,  l_rate: 0.000100
# Loss: 0.001,  l_rate: 0.000100
# Loss: 865.380,  l_rate: 0.000100
# Loss: 0.001,  l_rate: 0.000100
# Loss: 0.001,  l_rate: 0.000100
# Loss: 0.001,  l_rate: 0.000100
# Loss: 0.007,  l_rate: 0.000100
# Loss: 0.000,  l_rate: 0.000100
# Loss: 0.001,  l_rate: 0.000100
# Loss: 0.045,  l_rate: 0.000100
# Loss: 0.001,  l_rate: 0.000100
# Loss: 0.004,  l_rate: 0.000100
# Loss: 0.001,  l_rate: 0.000100
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-12-289f8506a4ae> in <module>()
#     322
#     323 if __name__ == "__main__":
# --> 324     main()
#     325
#     326
#
# <ipython-input-12-289f8506a4ae> in main()
#     298
#     299                         l_rate = (1e-5 - 1e-4)*(1/max_episode)*episode + 1e-4
# --> 300                         loss = ddqn_replay_train(mainDQN, targetDQN, minibatch, l_rate=l_rate)
#     301
#     302                         print("Loss: %.3f,  l_rate: %.6f" %(loss, l_rate))
#
# <ipython-input-12-289f8506a4ae> in ddqn_replay_train(mainDQN, targetDQN, train_batch, l_rate)
#      52     action_stack = np.empty(0).reshape(0, 60)
#      53     for state, action_seq, action_next_seq, action , reward, next_state, done in train_batch:
# ---> 54         Q = mainDQN(state, action_seq)
#      55         if done:
#      56             Q[0, action] = reward
#
# /usr/local/lib/python3.5/dist-packages/torch/nn/modules/module.py in __call__(self, *input, **kwargs)
#     355             result = self._slow_forward(*input, **kwargs)
#     356         else:
# --> 357             result = self.forward(*input, **kwargs)
#     358         for hook in self._forward_hooks.values():
#     359             hook_result = hook(self, input, result)
#
# <ipython-input-12-289f8506a4ae> in forward(self, x, y)
#     172         x = np.reshape(x, [-1, 224,256,15])
#     173         x = np.transpose(x, (0,3,1,2))
# --> 174         x = Variable(torch.Tensor(x)).type(FloatTensor)
#     175         y = Variable(torch.from_numpy(np.array(y))).type(FloatTensor)
#     176         x = self.model1(x)
#
# /usr/local/lib/python3.5/dist-packages/torch/autograd/variable.py in type(self, t)
#     283     def type(self, t):
#     284         if t != type(self.data):
# --> 285             return Type.apply(self, t)
#     286         return self
#     287
#
# /usr/local/lib/python3.5/dist-packages/torch/autograd/_functions/tensor.py in forward(ctx, i, dest_type)
#     179         ctx.input_type = type(i)
#     180         ctx.input_device = -1 if not i.is_cuda else i.get_device()
# --> 181         return i.type(dest_type)
#     182
#     183     @staticmethod
#
# /usr/local/lib/python3.5/dist-packages/torch/_utils.py in _type(self, new_type, async)
#      36     if new_type.is_sparse:
#      37         raise RuntimeError("Cannot cast dense tensor to sparse tensor")
# ---> 38     return new_type(self.size()).copy_(self, async)
#      39
#      40
#
# KeyboardInterrupt:
